# %% [markdown]
# <a href="https://colab.research.google.com/github/UmarIgan/Jupyter-Notebooks/blob/master/medical_trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries = ['Turkey', 'United State', 'United Kingdom', 'Canada', 'Germany', 'France', 'Italy', 'Spain']
countries_geo  = ['TR', 'USA', 'UK', 'C', 'G', 'FR', 'IT', 'SP']

cancers_tr = ['meme kanseri', 'prostat kanseri', 'akciğer kanseri']
cancers_usa = ['breast cancer', 'prostate cancer', 'lung cancer']
cancers_fr = ['cancer du sein', 'cancer de prostate', 'cancer de poumon']
cancers_gr = ['brustkrebs', 'prostatakrebs', 'lungenkrebs']
cancers_it = ['cancro al seno', 'cancro alla prostata', 'cancro al palmoni']
cancer_sp = ['cancer de mama', 'cancer de prostata', 'cancer de pulmon']

# %% [markdown]
# ## Data
# - This mdata mined from google trends for each country with that countries language

# %%
df = pd.read_csv("/Users/umar/Desktop/makale/cancer_goog_trends.csv")
df['Week'] = pd.to_datetime(df['Week'])
df['year_month'] = df['Week'].dt.to_period('M')
df['month'] = df['Week'].dt.month
df['year'] = df['Week'].dt.year
df.columns = ['week', 'breast_cancer', 'prostate_cancer', 'lung_cancer', 'country','year_month', 'month', 'year']
df.sample()
# Out:
#            week  breast_cancer  prostate_cancer  lung_cancer country  \
# 1675 2019-12-08              5               22           16   Spain
#
#      year_month  month  year
# 1675    2019-12     12  2019

# %% [markdown]
# ### monthly trends for each cancer type for each country

# %%
df_breast_m = df.sort_values(by = ['week', 'country']).groupby(['country', 'month'])['breast_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'country', values = 'breast_cancer')
df_prostate_ = df.sort_values(by = ['week', 'country']).groupby(['country', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'country', values = 'lung_cancer')
df_lung_m = df.sort_values(by = ['week', 'country']).groupby(['country', 'month'])['prostate_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'country', values = 'prostate_cancer')

# %% [markdown]
# ### year monthly trends for each cancer type for each country

# %%
df_breast_ym = df.groupby(['year_month', 'country'])['breast_cancer'].mean().reset_index().pivot_table(index = 'year_month', columns = 'country', values = 'breast_cancer')
df_prostate_ym = df.groupby(['year_month', 'country'])['lung_cancer'].mean().reset_index().pivot_table(index = 'year_month', columns = 'country', values = 'lung_cancer')
df_lung_ym = df.groupby(['year_month', 'country'])['prostate_cancer'].mean().reset_index().pivot_table(index = 'year_month', columns = 'country', values = 'prostate_cancer')

# %%
df.loc[df['country']=='Turkey'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "Turkey Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='United States'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "United States Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='United Kingdom'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "United Kingdom Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='France'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "France Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='Germany'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "Germany Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='Spain'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "Spain Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country']=='Italy'].groupby(['month', 'country'])[['prostate_cancer', 'breast_cancer']].mean().reset_index().set_index('month').plot(title = "Italy Breast vs Prostate Cancer")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly averages of search trends for each cancer type and country

# %%
df_breast_ym.plot(figsize = (8,5), title = "Montly Average of Breast Cancer Search Trend 2017-2022")
plt.tight_layout()
plt.show()

# %%
df_prostate_ym.plot(figsize = (8,5), title = "Montly Average of Prostate Cancer Search Trend 2017-2022")
plt.tight_layout()
plt.show()

# %%
df_lung_ym.plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend 2017-2022")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mean trend for each year's month for lung cancer

# %%
df.loc[df['country'] == 'Turkey'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for Turkey 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'France'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for France 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'United States'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for United States 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'United Kingdom'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for United Kingdom 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'Germany'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for Germany 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'Italy'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for Italy 2017-2022")
plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == 'Spain'].groupby(['year', 'month'])['lung_cancer'].mean().reset_index().pivot_table(index = 'month', columns = 'year', values = 'lung_cancer').plot(figsize = (8,5), title = "Montly Average of Lung Cancer Search Trend for Spain 2017-2022")
plt.tight_layout()
plt.show()
